# %%
list(set(
    ["RedA","BlueA","BlueA","RedA","GreenA","GreenA"] +
    ["IndigoA","RedB","SeagreenB","SalmonA","PurpleA","OrangeredA"] +
    ["BlueB","IndigoB","GrayB","TanB","LimegreenA","OrangeredB"] +
    ["TanB","GrayB","IndigoB","BlueB","OrangeredB","LimegreenB"] +
    ["SkyblueA","TanA","BrownA","SeagreenA","BlackA","OrangeA"] +
    ["GrayA","SkyblueB","SkyblueB","GrayA","OrangeB","OrangeB"] +
    ["SalmonA","SeagreenB","RedB","IndigoA","OrangeredA","PurpleB"] +
    ["BrownB","SalmonB","SalmonB","BrownB","BlackB","BlackB"] +
    ["SeagreenA","BrownA","TanA","SkyblueA","OrangeA","BlackA"] +
    ["RedA","BlueA","RedA","BlueA","GreenB","GreenB"] +
    ["IndigoA","RedB","SalmonA","SeagreenB","OrangeredA","PurpleB"] +
    ["BlueB","IndigoB","TanB","GrayB","OrangeredB","LimegreenB"] +
    ["SalmonA","SeagreenB","IndigoA","RedB","PurpleB","OrangeredA"] +
    ["BrownB","SalmonB","BrownB","SalmonB","BlackB","BlackB"] +
    ["SeagreenA","BrownA","SkyblueA","TanA","BlackA","OrangeA"] +
    ["TanB","GrayB","BlueB","IndigoB","LimegreenB","OrangeredB"] +
    ["SkyblueA","TanA","SeagreenA","BrownA","OrangeA","BlackA"] +
    ["GrayA","SkyblueB","GrayA","SkyblueB","OrangeB","OrangeB"] +
    ["BlueA","RedA","RedA","BlueA","GreenA","GreenA"] +
    ["IndigoB","BlueB","TanB","GrayB","LimegreenB","OrangeredB"]
))
# Out:
# ['SkyblueA',
#  'PurpleA',
#  'BrownA',
#  'OrangeredB',
#  'GreenB',
#  'SalmonA',
#  'TanA',
#  'GrayA',
#  'OrangeB',
#  'OrangeA',
#  'IndigoB',
#  'IndigoA',
#  'BrownB',
#  'GreenA',
#  'RedA',
#  'SkyblueB',
#  'PurpleB',
#  'BlackA',
#  'SalmonB',
#  'RedB',
#  'GrayB',
#  'LimegreenA',
#  'TanB',
#  'OrangeredA',
#  'SeagreenA',
#  'BlueB',
#  'BlueA',
#  'BlackB',
#  'SeagreenB',
#  'LimegreenB']
